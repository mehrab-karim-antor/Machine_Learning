# %% [markdown]
# <a href="https://colab.research.google.com/github/mehrab-karim-antor/Machine_Learning/blob/main/k_means_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# Sample 2D Data
X = np.array([
    [1, 2], [1.5, 1.8], [5, 8],
    [8, 8], [1, 0.6], [9, 11]
])

# Apply KMeans
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)

# Get results
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Visualization
plt.scatter(X[:, 0], X[:, 1], c=labels, s=100, cmap='rainbow')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, marker='X')
plt.title("K-Means Clustering Example (k=2)")
plt.show()

# Print Results
print("Cluster Centers:\n", centers)
print("Labels:", labels)
# Out:
# Cluster Centers:
#  [[7.33333333 9.        ]
#  [1.16666667 1.46666667]]
# Labels: [1 1 0 0 1 0]
